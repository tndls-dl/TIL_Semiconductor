# %%
import pandas as pd

oxide_df = pd.read_csv('02_oxide.csv')

oxide_df.head(10)
# Out:
#   process_date process_time equipment_id chamber_id wafer_id  \
# 0   2025-01-01      0:00:00         eq_1  chamber_1      w_0
# 1   2025-01-01      1:00:00         eq_2  chamber_2      w_1
# 2   2025-01-01      2:00:00         eq_3  chamber_3      w_2
# 3   2025-01-01      3:00:00         eq_4  chamber_1      w_3
# 4   2025-01-01      4:00:00         eq_5  chamber_2      w_4
# 5   2025-01-01      5:00:00         eq_1  chamber_3      w_5
# 6   2025-01-01      6:00:00         eq_2  chamber_1      w_6
# 7   2025-01-01      7:00:00         eq_3  chamber_2      w_7
# 8   2025-01-01      8:00:00         eq_4  chamber_3      w_8
# 9   2025-01-01      9:00:00         eq_5  chamber_1      w_9
#
#   wafer_doping_type  precleaning_time  oxidation_temperature  oxidation_time  \
# 0            p-type                 3             908.332942       30.450712
# 1            n-type                 1             998.595807       43.926035
# ...

# %%
oxide_df['process_datetime'] = pd.to_datetime(oxide_df['process_date'] + ' ' + oxide_df['process_time']) 

oxide_df.head(20)
# Out:
#    process_date process_time equipment_id chamber_id wafer_id  \
# 0    2025-01-01      0:00:00         eq_1  chamber_1      w_0
# 1    2025-01-01      1:00:00         eq_2  chamber_2      w_1
# 2    2025-01-01      2:00:00         eq_3  chamber_3      w_2
# 3    2025-01-01      3:00:00         eq_4  chamber_1      w_3
# 4    2025-01-01      4:00:00         eq_5  chamber_2      w_4
# 5    2025-01-01      5:00:00         eq_1  chamber_3      w_5
# 6    2025-01-01      6:00:00         eq_2  chamber_1      w_6
# 7    2025-01-01      7:00:00         eq_3  chamber_2      w_7
# 8    2025-01-01      8:00:00         eq_4  chamber_3      w_8
# 9    2025-01-01      9:00:00         eq_5  chamber_1      w_9
# 10   2025-01-01     10:00:00         eq_1  chamber_2     w_10
# 11   2025-01-01     11:00:00         eq_2  chamber_3     w_11
# 12   2025-01-01     12:00:00         eq_3  chamber_1     w_12
# 13   2025-01-01     13:00:00         eq_4  chamber_2     w_13
# ...

# %%
oxide_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   process_date           1000 non-null   object
#  1   process_time           1000 non-null   object
#  2   equipment_id           1000 non-null   object
#  3   chamber_id             1000 non-null   object
#  4   wafer_id               1000 non-null   object
#  5   wafer_doping_type      1000 non-null   object
#  6   precleaning_time       1000 non-null   int64
#  7   oxidation_temperature  999 non-null    float64
#  8   oxidation_time         1000 non-null   float64
#  9   pressure               995 non-null    float64
#  10  gas_flow_rate          1000 non-null   float64
#  11  oxide_thickness        999 non-null    float64
#  12  uniformity             989 non-null    float64
#  13  defect_count           1000 non-null   int64
# ...

# %%
oxide_df.isna().sum()
# Out:
# process_date              0
# process_time              0
# equipment_id              0
# chamber_id                0
# wafer_id                  0
# wafer_doping_type         0
# precleaning_time          0
# oxidation_temperature     1
# oxidation_time            0
# pressure                  5
# gas_flow_rate             0
# oxide_thickness           1
# uniformity               11
# defect_count              0
# defect_type               0
# process_datetime          0
# dtype: int64

# %%
from IPython.display import display

a = oxide_df[oxide_df['oxidation_temperature'].isnull()]
b = oxide_df[oxide_df['pressure'].isnull()]
c = oxide_df[oxide_df['oxide_thickness'].isnull()]
d = oxide_df[oxide_df['uniformity'].isnull()]

print("=== oxidation_temperature null값 ===\n")
display(a)
print("=== pressure null값 ===")
display(b)
print("=== oxide_thickness null값 ===")
display(c)
print("=== uniformity null값 ===")
display(d)
# Out:
# === oxidation_temperature null값 ===
#    process_date process_time equipment_id chamber_id wafer_id  \
# 68   2025-01-03     20:00:00         eq_4  chamber_3     w_68
#
#    wafer_doping_type  precleaning_time  oxidation_temperature  oxidation_time  \
# 68            n-type                 4                    NaN        62.42454
#
#     pressure  gas_flow_rate  oxide_thickness  uniformity  defect_count  \
# 68  0.997254    3556.431388       444.176287         NaN             0
#
#    defect_type    process_datetime
# 68        none 2025-01-03 20:00:00
# === pressure null값 ===
#     process_date process_time equipment_id chamber_id wafer_id  \
# 154   2025-01-07     10:00:00         eq_5  chamber_2    w_154
# 283   2025-01-12     19:00:00         eq_4  chamber_2    w_283
# 370   2025-01-16     10:00:00         eq_1  chamber_2    w_370
# 668   2025-01-28     20:00:00         eq_4  chamber_3    w_668
# 674   2025-01-29      2:00:00         eq_5  chamber_3    w_674
#
# ...

# %%
df1 = oxide_df[oxide_df['defect_type'] == 'none']
df1
# Out:
#     process_date process_time equipment_id chamber_id wafer_id  \
# 0     2025-01-01      0:00:00         eq_1  chamber_1      w_0
# 4     2025-01-01      4:00:00         eq_5  chamber_2      w_4
# 5     2025-01-01      5:00:00         eq_1  chamber_3      w_5
# 6     2025-01-01      6:00:00         eq_2  chamber_1      w_6
# 7     2025-01-01      7:00:00         eq_3  chamber_2      w_7
# ..           ...          ...          ...        ...      ...
# 993   2025-02-11      9:00:00         eq_4  chamber_1    w_993
# 994   2025-02-11     10:00:00         eq_5  chamber_2    w_994
# 995   2025-02-11     11:00:00         eq_1  chamber_3    w_995
# 996   2025-02-11     12:00:00         eq_2  chamber_1    w_996
# 997   2025-02-11     13:00:00         eq_3  chamber_2    w_997
#
#     wafer_doping_type  precleaning_time  oxidation_temperature  \
# 0              p-type                 3             908.332942
# 4              p-type                 3             968.690498
# ...

# %%
oxide_thickness = oxide_df['oxide_thickness']

target_thickness = oxide_thickness.median()
print(f"목표값: {target_thickness:.2f}")

std_thickness = oxide_thickness.std()
print(f"표준 편차: {std_thickness:.2f}")

# 허용 범위
lower_limit = target_thickness - 3 * std_thickness  # 하한 값 (목표 값 - 3σ)
upper_limit = target_thickness + 3 * std_thickness  # 상한 값 (목표 값 + 3σ)

print(f"허용 범위: {lower_limit:.2f} ~ {upper_limit:.2f}")
# Out:
# 목표값: 310.52
# 표준 편차: 91.63
# 허용 범위: 35.61 ~ 585.42
